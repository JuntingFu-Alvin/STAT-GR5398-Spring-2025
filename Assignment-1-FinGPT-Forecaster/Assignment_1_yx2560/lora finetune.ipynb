# %% [markdown]
# ### Set up, all comment out

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/AI4Finance/

# %%
# !git clone https://github.com/AI4Finance-Foundation/FinGPT.git

# %%
# %cd FinGPT/fingpt/FinGPT_Forecaster

# %%
# from datasets import load_dataset
# dataset = load_dataset("FinGPT/fingpt-forecaster-dow30-202305-202405")
# dataset.save_to_disk("/content/drive/MyDrive/AI4Finance/FinGPT_Forecaster_Dataset")

# %% [markdown]
# ## Run

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/AI4Finance/FinGPT/fingpt/FinGPT_Forecaster
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/AI4Finance/FinGPT/fingpt/FinGPT_Forecaster

# %%
# %%capture
# !pip install -r ../../requirements.txt

# %%
# %%capture
# !pip install rouge-score
# !pip install torch transformers peft datasets accelerate bitsandbytes
# !pip install "peft==0.4.0" "transformers>=4.36.0" "bitsandbytes>=0.41.0"
# !pip install deepspeed>=0.9.3
# !pip install mpi4py

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Feb 25 19:08:44 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0             46W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
import torch
print("GPU available:", torch.cuda.is_available())
# Out:
# GPU available: True

# %%
from huggingface_hub import login
from google.colab import userdata
hf_token = userdata.get('HF_API')
login(hf_token)

# %%
import os
os.environ['WANDB_API_KEY'] = userdata.get('wandb_API')

# %%
# !python train_lora.py \
    --dataset /content/drive/MyDrive/AI4Finance/FinGPT_Forecaster_Dataset \
    --base_model deepseek \
    --max_length 4096\
    --num_epochs 3 \
    --batch_size 2 \
    --gradient_accumulation_steps 16 \
    --num_workers 2 \
    --learning_rate 5e-5 \
    --evaluation_strategy steps \
    --eval_steps 20
# Out:
# 2025-02-25 19:09:27.003453: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-25 19:09:27.020900: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740510567.042773    7462 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740510567.049402    7462 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train_lora.py \
    --dataset /content/drive/MyDrive/AI4Finance/FinGPT_Forecaster_Dataset \
    --base_model llama3.1 \
    --max_length 4096\
    --num_epochs 3 \
    --batch_size 2 \
    --gradient_accumulation_steps 16 \
    --num_workers 2 \
    --learning_rate 5e-5 \
    --evaluation_strategy steps \
    --eval_steps 20
# Out:
# 2025-02-25 21:48:46.773091: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-25 21:48:46.791893: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740520126.814859   47189 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740520126.821726   47189 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train_lora.py \
    --dataset /content/drive/MyDrive/AI4Finance/FinGPT_Forecaster_Dataset \
    --base_model llama3.1 \
    --max_length 4096\
    --num_epochs 3 \
    --batch_size 2 \
    --gradient_accumulation_steps 16 \
    --num_workers 2 \
    --learning_rate 5e-5
#deepspeed
# Out:
# 2025-02-07 05:37:55.613030: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-07 05:37:55.631964: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738906675.654124   11154 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738906675.660873   11154 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
