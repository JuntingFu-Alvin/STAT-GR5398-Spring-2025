# %% [markdown]
# First import requirements.txt into your contents folder.

# %% [markdown]
# ## Installations

# %%
# !pip install -r /content/requirements.txt --quiet
# !pip install datasets --quiet
# !pip install utils --quiet

# %%
# !pip show transformers
# Out:
# Name: transformers
# Version: 4.32.0
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by: peft, sentence-transformers

# %%
# !pip install transformers==4.41.0 --quiet

# %%
# !pip show transformers
# Out:
# Name: transformers
# Version: 4.41.0
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by: peft, sentence-transformers

# %%
import os
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from datasets import load_from_disk, load_dataset
from peft import PeftModel
from utils import *
os.environ['CUDA_VISIBLE_DEVICES'] = "5,6"

# %% [markdown]
# ## Load Model - **Llama3-8b model**

# %%
token = "{insert key}" #Get token from - https://huggingface.co/

# %%
base_model = AutoModelForCausalLM.from_pretrained(
    'meta-llama/Llama-2-7b-chat-hf',
    trust_remote_code=True,
    device_map="auto",
    torch_dtype=torch.float16,   # optional if you have enough VRAM
    use_auth_token = token
)

tokenizer = AutoTokenizer.from_pretrained('meta-llama/Llama-2-7b-chat-hf',
                                          use_auth_token = token
                                          )

tokenizer.padding_side = "right"
tokenizer.pad_token_id = tokenizer.eos_token_id

model = PeftModel.from_pretrained(base_model,
                                  'FinGPT/fingpt-forecaster_dow30_llama2-7b_lora',
                                  use_auth_token = token
                                  )
model = model.eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py:468: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:769: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/528 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/40.0M [00:00<?, ?B/s]

# %% [markdown]
# ## Prepare Data for FinGPT Forecaster

# %% [markdown]
# Load relevant libraries.

# %%
import re
import csv
import math
import time
import json
import random
import finnhub
import datasets
import pandas as pd
import yfinance as yf
from datetime import datetime
from collections import defaultdict
from datasets import Dataset
from openai import OpenAI

# %%
finnhub_key = "{key}"

# %%
START_DATE = "2022-12-31"
END_DATE = "2023-05-31"

DATA_DIR = f"./{START_DATE}_{END_DATE}"
os.makedirs(DATA_DIR, exist_ok=True)

finnhub_client = finnhub.Client(api_key = finnhub_key)

client = OpenAI(api_key = 'your openai key')

# %%
def bin_mapping(ret):

    up_down = 'U' if ret >= 0 else 'D'
    integer = math.ceil(abs(100 * ret))

    return up_down + (str(integer) if integer <= 5 else '5+')


def get_returns(stock_symbol):

    # Download historical stock data
    stock_data = yf.download(stock_symbol, start=START_DATE, end=END_DATE, auto_adjust=False)

    weekly_data = stock_data['Adj Close'].resample('W').ffill()
    weekly_returns = weekly_data.pct_change()[1:]
    weekly_start_prices = weekly_data[:-1]
    weekly_end_prices = weekly_data[1:]

    weekly_data = pd.DataFrame({
        'Start Date': weekly_start_prices.index,
        'Start Price': weekly_start_prices.values.ravel(),
        'End Date': weekly_end_prices.index,
        'End Price': weekly_end_prices.values.ravel(),
        'Weekly Returns': weekly_returns.values.ravel()
    })

    weekly_data['Bin Label'] = weekly_data['Weekly Returns'].map(bin_mapping)

    return weekly_data

def get_news(symbol, data):

    news_list = []

    for end_date, row in data.iterrows():
        start_date = row['Start Date'].strftime('%Y-%m-%d')
        end_date = row['End Date'].strftime('%Y-%m-%d')
        print(symbol, ': ', start_date, ' - ', end_date)
        time.sleep(1) # control qpm
        weekly_news = finnhub_client.company_news(symbol, _from=start_date, to=end_date)
        weekly_news = [
            {
                "date": datetime.fromtimestamp(n['datetime']).strftime('%Y%m%d%H%M%S'),
                "headline": n['headline'],
                "summary": n['summary'],
            } for n in weekly_news
        ]
        weekly_news.sort(key=lambda x: x['date'])
        news_list.append(json.dumps(weekly_news))

    data['News'] = news_list

    return data


def get_basics(symbol, data, always=False):

    basic_financials = finnhub_client.company_basic_financials(symbol, 'all')

    final_basics, basic_list, basic_dict = [], [], defaultdict(dict)

    for metric, value_list in basic_financials['series']['quarterly'].items():
        for value in value_list:
            basic_dict[value['period']].update({metric: value['v']})

    for k, v in basic_dict.items():
        v.update({'period': k})
        basic_list.append(v)

    basic_list.sort(key=lambda x: x['period'])

    for i, row in data.iterrows():

        start_date = row['End Date'].strftime('%Y-%m-%d')
        last_start_date = START_DATE if i < 2 else data.loc[i-2, 'Start Date'].strftime('%Y-%m-%d')

        used_basic = {}
        for basic in basic_list[::-1]:
            if (always and basic['period'] < start_date) or (last_start_date <= basic['period'] < start_date):
                used_basic = basic
                break
        final_basics.append(json.dumps(used_basic))

    data['Basics'] = final_basics

    return data


def prepare_data_for_company(symbol, with_basics=True):

    data = get_returns(symbol)
    data = get_news(symbol, data)

    if with_basics:
        data = get_basics(symbol, data)
        data.to_csv(f"{DATA_DIR}/{symbol}_{START_DATE}_{END_DATE}.csv")
    else:
        data['Basics'] = [json.dumps({})] * len(data)
        data.to_csv(f"{DATA_DIR}/{symbol}_{START_DATE}_{END_DATE}_nobasics.csv")

    return data

# %%
DOW_30 = [
    "AXP", "AMGN", "AAPL", "BA", "CAT", "CSCO", "CVX", "GS", "HD", "HON",
    "IBM", "INTC", "JNJ", "KO", "JPM", "MCD", "MMM", "MRK", "MSFT", "NKE",
    "PG", "TRV", "UNH", "CRM", "VZ", "V", "WBA", "WMT", "DIS", "DOW"
]

# prepare_data_for_company("DOW", False)

# %%
for symbol in DOW_30:
    prepare_data_for_company(symbol)
#     prepare_data_for_company(symbol, False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# AXP :  2023-01-08  -  2023-01-15
# AXP :  2023-01-15  -  2023-01-22
# AXP :  2023-01-22  -  2023-01-29
# AXP :  2023-01-29  -  2023-02-05
# AXP :  2023-02-05  -  2023-02-12
# AXP :  2023-02-12  -  2023-02-19
# AXP :  2023-02-19  -  2023-02-26
# AXP :  2023-02-26  -  2023-03-05
# AXP :  2023-03-05  -  2023-03-12
# AXP :  2023-03-12  -  2023-03-19
# AXP :  2023-03-19  -  2023-03-26
# AXP :  2023-03-26  -  2023-04-02
# AXP :  2023-04-02  -  2023-04-09
# AXP :  2023-04-09  -  2023-04-16
# AXP :  2023-04-16  -  2023-04-23
# AXP :  2023-04-23  -  2023-04-30
# AXP :  2023-04-30  -  2023-05-07
# AXP :  2023-05-07  -  2023-05-14
# AXP :  2023-05-14  -  2023-05-21
# AXP :  2023-05-21  -  2023-05-28
# AXP :  2023-05-28  -  2023-06-04
# [*********************100%***********************]  1 of 1 completed
# DIS :  2023-03-26  -  2023-04-02
# DIS :  2023-04-02  -  2023-04-09
# DIS :  2023-04-09  -  2023-04-16
# DIS :  2023-04-16  -  2023-04-23
# DIS :  2023-04-23  -  2023-04-30
# DIS :  2023-04-30  -  2023-05-07
# DIS :  2023-05-07  -  2023-05-14
# DIS :  2023-05-14  -  2023-05-21
# DIS :  2023-05-21  -  2023-05-28
# DIS :  2023-05-28  -  2023-06-04
# [*********************100%***********************]  1 of 1 completed
# DOW :  2023-01-08  -  2023-01-15
# DOW :  2023-01-15  -  2023-01-22
# DOW :  2023-01-22  -  2023-01-29
# DOW :  2023-01-29  -  2023-02-05
# DOW :  2023-02-05  -  2023-02-12
# DOW :  2023-02-12  -  2023-02-19
# DOW :  2023-02-19  -  2023-02-26
# DOW :  2023-02-26  -  2023-03-05
# DOW :  2023-03-05  -  2023-03-12
# DOW :  2023-03-12  -  2023-03-19
# DOW :  2023-03-19  -  2023-03-26
# DOW :  2023-03-26  -  2023-04-02
# DOW :  2023-04-02  -  2023-04-09
# DOW :  2023-04-09  -  2023-04-16
# DOW :  2023-04-16  -  2023-04-23
# DOW :  2023-04-23  -  2023-04-30
# DOW :  2023-04-30  -  2023-05-07
# DOW :  2023-05-07  -  2023-05-14
# DOW :  2023-05-14  -  2023-05-21
# DOW :  2023-05-21  -  2023-05-28
# DOW :  2023-05-28  -  2023-06-04

# %%
def get_company_prompt(symbol):

    profile = finnhub_client.company_profile2(symbol=symbol)

    company_template = "[Company Introduction]:\n\n{name} is a leading entity in the {finnhubIndustry} sector. Incorporated and publicly traded since {ipo}, the company has established its reputation as one of the key players in the market. As of today, {name} has a market capitalization of {marketCapitalization:.2f} in {currency}, with {shareOutstanding:.2f} shares outstanding." \
        "\n\n{name} operates primarily in the {country}, trading under the ticker {ticker} on the {exchange}. As a dominant force in the {finnhubIndustry} space, the company continues to innovate and drive progress within the industry."

    formatted_str = company_template.format(**profile)

    return formatted_str


def get_prompt_by_row(symbol, row):

    start_date = row['Start Date'] if isinstance(row['Start Date'], str) else row['Start Date'].strftime('%Y-%m-%d')
    end_date = row['End Date'] if isinstance(row['End Date'], str) else row['End Date'].strftime('%Y-%m-%d')
    term = 'increased' if row['End Price'] > row['Start Price'] else 'decreased'
    head = "From {} to {}, {}'s stock price {} from {:.2f} to {:.2f}. Company news during this period are listed below:\n\n".format(
        start_date, end_date, symbol, term, row['Start Price'], row['End Price'])

    news = json.loads(row["News"])
    news = ["[Headline]: {}\n[Summary]: {}\n".format(
        n['headline'], n['summary']) for n in news if n['date'][:8] <= end_date.replace('-', '') and \
        not n['summary'].startswith("Looking for stock market analysis and research with proves results?")]

    basics = json.loads(row['Basics'])
    if basics:
        basics = "Some recent basic financials of {}, reported at {}, are presented below:\n\n[Basic Financials]:\n\n".format(
            symbol, basics['period']) + "\n".join(f"{k}: {v}" for k, v in basics.items() if k != 'period')
    else:
        basics = "[Basic Financials]:\n\nNo basic financial reported."

    return head, news, basics


def sample_news(news, k=5):

    return [news[i] for i in sorted(random.sample(range(len(news)), k))]


def map_bin_label(bin_lb):

    lb = bin_lb.replace('U', 'up by ')
    lb = lb.replace('D', 'down by ')
    lb = lb.replace('1', '0-1%')
    lb = lb.replace('2', '1-2%')
    lb = lb.replace('3', '2-3%')
    lb = lb.replace('4', '3-4%')
    if lb.endswith('+'):
        lb = lb.replace('5+', 'more than 5%')
#         lb = lb.replace('5+', '5+%')
    else:
        lb = lb.replace('5', '4-5%')

    return lb


def get_all_prompts(symbol, min_past_weeks=1, max_past_weeks=3, with_basics=True):


    if with_basics:
        df = pd.read_csv(f'{DATA_DIR}/{symbol}_{START_DATE}_{END_DATE}.csv')
    else:
        df = pd.read_csv(f'{DATA_DIR}/{symbol}_{START_DATE}_{END_DATE}_nobasics.csv')

    company_prompt = get_company_prompt(symbol)

    prev_rows = []
    all_prompts = []

    for row_idx, row in df.iterrows():

        prompt = ""
        if len(prev_rows) >= min_past_weeks:
            idx = min(random.choice(range(min_past_weeks, max_past_weeks+1)), len(prev_rows))
            for i in range(-idx, 0):
                # Add Price Movement (Head)
                prompt += "\n" + prev_rows[i][0]
                # Add News of previous weeks
                sampled_news = sample_news(
                    prev_rows[i][1],
                    min(5, len(prev_rows[i][1]))
                )
                if sampled_news:
                    prompt += "\n".join(sampled_news)
                else:
                    prompt += "No relative news reported."

        head, news, basics = get_prompt_by_row(symbol, row)

        prev_rows.append((head, news, basics))
        if len(prev_rows) > max_past_weeks:
            prev_rows.pop(0)

        if not prompt:
            continue

        prediction = map_bin_label(row['Bin Label'])

        prompt = company_prompt + '\n' + prompt + '\n' + basics
        prompt += f"\n\nBased on all the information before {row['Start Date']}, let's first analyze the positive developments and potential concerns for {symbol}. Come up with 2-4 most important factors respectively and keep them concise. Most factors should be inferred from company related news. " \
            f"Then let's assume your prediction for next week ({row['Start Date']} to {row['End Date']}) is {prediction}. Provide a summary analysis to support your prediction. The prediction result need to be inferred from your analysis at the end, and thus not appearing as a foundational factor of your analysis."

        all_prompts.append(prompt.strip())

    return all_prompts

# %%
B_INST, E_INST = "[INST]", "[/INST]"
B_SYS, E_SYS = "<<SYS>>\n", "\n<</SYS>>\n\n"


SYSTEM_PROMPT = "You are a seasoned stock market analyst. Your task is to list the positive developments and potential concerns for companies based on relevant news and basic financials from the past weeks, then provide an analysis and prediction for the companies' stock price movement for the upcoming week. " \
    "Your answer format should be as follows:\n\n[Positive Developments]:\n1. ...\n\n[Potential Concerns]:\n1. ...\n\n[Prediction & Analysis]:\n...\n"

print(SYSTEM_PROMPT)

# prompts = get_all_prompts("AAPL", 1, 3)
# prompts = get_all_prompts("MSFT", 1, 3, False)
prompts = get_all_prompts("TRV", 1, 4)

print(prompts[0])
# Out:
# You are a seasoned stock market analyst. Your task is to list the positive developments and potential concerns for companies based on relevant news and basic financials from the past weeks, then provide an analysis and prediction for the companies' stock price movement for the upcoming week. Your answer format should be as follows:
#
# [Positive Developments]:
# 1. ...
#
# [Potential Concerns]:
# 1. ...
#
# [Prediction & Analysis]:
# ...
#
# [Company Introduction]:
#
# Travelers Companies Inc is a leading entity in the Insurance sector. Incorporated and publicly traded since 1980-03-17, the company has established its reputation as one of the key players in the market. As of today, Travelers Companies Inc has a market capitalization of 55018.05 in USD, with 227.02 shares outstanding.
#
# Travelers Companies Inc operates primarily in the US, trading under the ticker TRV on the NEW YORK STOCK EXCHANGE, INC.. As a dominant force in the Insurance space, the company continues to innovate and drive progress within the industry.
#
# From 2023-01-08 to 2023-01-15, TRV's stock price increased from 186.14 to 186.19. Company news during this period are listed below:
#
# No relative news reported.
# Some recent basic financials of TRV, reported at 2022-12-31, are presented below:
#
# [Basic Financials]:
#
# assetTurnoverTTM: 0.3175
# bookValue: 21560
# cashRatio: 0.21617965367965367
# ebitPerShare: 4.5659
# eps: 3.4689
# ev: 50430.8
# fcfMargin: 0.139
# fcfPerShareTTM: 27.8544
# longtermDebtTotalAsset: 0.0622
# longtermDebtTotalCapital: 0.2493
# longtermDebtTotalEquity: 0.3336
# netDebtToTotalCapital: 0.225
# netDebtToTotalEquity: 0.3012
# netMargin: 0.085
# operatingMargin: 0.1118
# payoutRatioTTM: 0.3079
# pb: 2.0379
# peTTM: 15.4602
# pfcfTTM: 6.7963
# pretaxMargin: 0.1024
# psTTM: 1.19
# ptbv: 2.0654
# roaTTM: 0.0244
# roeTTM: 0.1265
# roicTTM: 0.0955
# rotcTTM: 0.1249
# salesPerShare: 40.8259
# tangibleBookValue: 21273
# totalDebtToEquity: 0.3382
# totalDebtToTotalAsset: 0.063
# totalDebtToTotalCapital: 0.2527
# totalRatio: 1.229
#
# Based on all the information before 2023-01-15, let's first analyze the positive developments and potential concerns for TRV. Come up with 2-4 most important factors respectively and keep them concise. Most factors should be inferred from company related news. Then let's assume your prediction for next week (2023-01-15 to 2023-01-22) is down by 4-5%. Provide a summary analysis to support your prediction. The prediction result need to be inferred from your analysis at the end, and thus not appearing as a foundational factor of your analysis.

# %%
def append_to_csv(filename, input_data, output_data):

    with open(filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([input_data, output_data])


def initialize_csv(filename):

    with open(filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["prompt", "answer"])


def query_gpt4(symbol_list, min_past_weeks=1, max_past_weeks=3, with_basics=True):

    for symbol in symbol_list:

        csv_file = f'{DATA_DIR}/{symbol}_{START_DATE}_{END_DATE}_gpt-4.csv' if with_basics else \
                   f'{DATA_DIR}/{symbol}_{START_DATE}_{END_DATE}_nobasics_gpt-4.csv'

        if not os.path.exists(csv_file):
            initialize_csv(csv_file)
            pre_done = 0
        else:
            df = pd.read_csv(csv_file)
            pre_done = len(df)

        prompts = get_all_prompts(symbol, min_past_weeks, max_past_weeks, with_basics)

        for i, prompt in enumerate(prompts):

            if i < pre_done:
                continue

            print(f"{symbol} - {i}")

            cnt = 0
            while cnt < 5:
                try:
                    completion = client.chat.completions.create(
                        model="gpt-4",
                        messages=[
                            {"role": "system", "content": SYSTEM_PROMPT},
                            {"role": "user", "content": prompt}
                          ]
                    )
                    break
                except Exception:
                    cnt += 1
                    print(f'retry cnt {cnt}')

            answer = completion.choices[0].message.content if cnt < 5 else ""
            append_to_csv(csv_file, prompt, answer)

# %%
# query_gpt4(DOW_30, 1, 3)
query_gpt4(DOW_30, 1, 4)
# query_gpt4(['WBA'], 1, 4)
# Out:
# AXP - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AXP - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AMGN - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# AAPL - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# BA - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CAT - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CSCO - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CVX - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# GS - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HD - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# HON - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# IBM - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# INTC - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JNJ - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# KO - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# JPM - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MCD - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MMM - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MRK - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# MSFT - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# NKE - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# PG - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# TRV - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# UNH - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# CRM - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# VZ - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# V - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WBA - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# WMT - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DIS - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 0
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 1
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 2
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 3
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 4
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 5
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 6
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 7
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 8
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 9
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 10
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 11
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 12
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 13
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 14
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 15
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 16
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 17
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 18
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5
# DOW - 19
# retry cnt 1
# retry cnt 2
# retry cnt 3
# retry cnt 4
# retry cnt 5

# %%
def gpt4_to_llama(symbol, with_basics=True):

    csv_file = f'{DATA_DIR}/{symbol}_{START_DATE}_{END_DATE}_gpt-4.csv' if with_basics else \
                   f'{DATA_DIR}/{symbol}_{START_DATE}_{END_DATE}_nobasics_gpt-4.csv'

    df = pd.read_csv(csv_file)

    prompts, answers, periods, labels = [], [], [], []

    for i, row in df.iterrows():

        prompt, answer = row['prompt'], row['answer']

        res = re.search(r"Then let's assume your prediction for next week \((.*)\) is ((:?up|down) by .*%).", prompt)

        period, label = res.group(1), res.group(2)
#         label = label.replace('more than 5', '5+')

        prompt = re.sub(
            r"Then let's assume your prediction for next week \((.*)\) is (up|down) by ((:?.*)%). Provide a summary analysis to support your prediction. The prediction result need to be inferred from your analysis at the end, and thus not appearing as a foundational factor of your analysis.",
            f"Then make your prediction of the {symbol} stock price movement for next week ({period}). Provide a summary analysis to support your prediction.",
            prompt
        )
        try:
            answer = re.sub(
                r"\[Prediction & Analysis\]:\s*",
                f"[Prediction & Analysis]:\nPrediction: {label.capitalize()}\nAnalysis: ",
                answer
            )
        except Exception:
            print(symbol, i)
            print(label)
            print(answer)
            continue

        new_system_prompt = SYSTEM_PROMPT.replace(':\n...', '\nPrediction: ...\nAnalysis: ...')
#         new_system_prompt = SYSTEM_PROMPT.replace(':\n...', '\nPrediction: {Up|Down} by {1-2|2-3|3-4|4-5|5+}%\nAnalysis: ...')

        prompt = B_INST + B_SYS + new_system_prompt + E_SYS + prompt + E_INST

        prompts.append(prompt)
        answers.append(answer)
        periods.append(period)
        labels.append(label)

    return {
        "prompt": prompts,
        "answer": answers,
        "period": periods,
        "label": labels,
    }


def create_dataset(symbol_list, train_ratio=0.8, with_basics=True):

    train_dataset_list = []
    test_dataset_list = []

    for symbol in symbol_list:

        data_dict = gpt4_to_llama(symbol, with_basics)
#         print(data_dict['prompt'][-1])
#         print(data_dict['answer'][-1])
        symbols = [symbol] * len(data_dict['label'])
        data_dict.update({"symbol": symbols})

        dataset = Dataset.from_dict(data_dict)
        train_size = round(train_ratio * len(dataset))

        train_dataset_list.append(dataset.select(range(train_size)))
        test_dataset_list.append(dataset.select(range(train_size, len(dataset))))

    train_dataset = datasets.concatenate_datasets(train_dataset_list)
    test_dataset = datasets.concatenate_datasets(test_dataset_list)

    dataset = datasets.DatasetDict({
        'train': train_dataset,
        'test': test_dataset
    })

    return dataset

# %%
dow30_v3_dataset = create_dataset(DOW_30, 0.9)
# Out:
# AXP 0
# down by 2-3%
# nan
# AXP 1
# up by more than 5%
# nan
# AXP 2
# up by 3-4%
# nan
# AXP 3
# up by 0-1%
# nan
# AXP 4
# down by 1-2%
# nan
# AXP 5
# down by 1-2%
# nan
# AXP 6
# up by 2-3%
# nan
# AXP 7
# down by more than 5%
# nan
# AXP 8
# down by more than 5%
# nan
# AXP 9
# up by 2-3%
# nan
# AXP 10
# up by 3-4%
# nan
# AXP 11
# down by 3-4%
# nan
# AXP 12
# up by 2-3%
# nan
# AXP 13
# up by 0-1%
# nan
# AXP 14
# down by 1-2%
# nan
# AXP 15
# down by more than 5%
# nan
# AXP 16
# down by 3-4%
# nan
# AXP 17
# up by 3-4%
# nan
# AXP 18
# up by 2-3%
# nan
# AXP 19
# up by 0-1%
# nan
# AMGN 0
# down by 3-4%
# nan
# AMGN 1
# down by 3-4%
# nan
# AMGN 2
# down by 3-4%
# nan
# AMGN 3
# down by 1-2%
# nan
# AMGN 4
# up by 0-1%
# nan
# AMGN 5
# down by 2-3%
# nan
# AMGN 6
# up by 0-1%
# nan
# AMGN 7
# down by 2-3%
# nan
# AMGN 8
# up by 0-1%
# nan
# AMGN 9
# up by 3-4%
# nan
# AMGN 10
# up by 1-2%
# nan
# AMGN 11
# up by 4-5%
# nan
# AMGN 12
# down by 1-2%
# nan
# AMGN 13
# down by 2-3%
# nan
# AMGN 14
# down by 1-2%
# nan
# AMGN 15
# down by 1-2%
# nan
# AMGN 16
# down by 1-2%
# nan
# AMGN 17
# down by 3-4%
# nan
# AMGN 18
# down by 2-3%
# nan
# AMGN 19
# up by 0-1%
# nan
# AAPL 0
# up by 2-3%
# nan
# AAPL 1
# up by more than 5%
# nan
# AAPL 2
# up by more than 5%
# nan
# AAPL 3
# down by 2-3%
# nan
# AAPL 4
# up by 1-2%
# nan
# AAPL 5
# down by 3-4%
# nan
# AAPL 6
# up by 2-3%
# nan
# AAPL 7
# down by 1-2%
# nan
# AAPL 8
# up by 4-5%
# nan
# AAPL 9
# up by 3-4%
# nan
# AAPL 10
# up by 2-3%
# nan
# AAPL 11
# down by 0-1%
# nan
# AAPL 12
# up by 0-1%
# nan
# AAPL 13
# down by 0-1%
# nan
# AAPL 14
# up by 2-3%
# nan
# AAPL 15
# up by 2-3%
# nan
# AAPL 16
# down by 0-1%
# nan
# AAPL 17
# up by 1-2%
# nan
# AAPL 18
# up by 0-1%
# nan
# AAPL 19
# up by 1-2%
# nan
# BA 0
# down by 3-4%
# nan
# BA 1
# up by 2-3%
# nan
# BA 2
# down by 2-3%
# nan
# BA 3
# up by 3-4%
# nan
# BA 4
# down by 0-1%
# nan
# BA 5
# down by more than 5%
# nan
# BA 6
# up by more than 5%
# nan
# BA 7
# down by more than 5%
# nan
# BA 8
# down by 0-1%
# nan
# BA 9
# down by 1-2%
# nan
# BA 10
# up by more than 5%
# nan
# BA 11
# down by 0-1%
# nan
# BA 12
# down by 4-5%
# nan
# BA 13
# up by 1-2%
# nan
# BA 14
# up by 0-1%
# nan
# BA 15
# down by 4-5%
# nan
# BA 16
# up by 1-2%
# nan
# BA 17
# up by 2-3%
# nan
# BA 18
# down by 0-1%
# nan
# BA 19
# up by 0-1%
# nan
# CAT 0
# down by 2-3%
# nan
# CAT 1
# up by more than 5%
# nan
# CAT 2
# down by more than 5%
# nan
# CAT 3
# down by 0-1%
# nan
# CAT 4
# up by 0-1%
# nan
# CAT 5
# down by 4-5%
# nan
# CAT 6
# up by more than 5%
# nan
# CAT 7
# down by more than 5%
# nan
# CAT 8
# down by more than 5%
# nan
# CAT 9
# up by 0-1%
# nan
# CAT 10
# up by more than 5%
# nan
# CAT 11
# down by more than 5%
# nan
# CAT 12
# up by more than 5%
# nan
# CAT 13
# down by 0-1%
# nan
# CAT 14
# down by 0-1%
# nan
# CAT 15
# down by 1-2%
# nan
# CAT 16
# down by 2-3%
# nan
# CAT 17
# up by 2-3%
# nan
# CAT 18
# down by 1-2%
# nan
# CAT 19
# down by 0-1%
# nan
# CSCO 0
# down by 4-5%
# nan
# CSCO 1
# up by 3-4%
# nan
# CSCO 2
# up by 0-1%
# nan
# CSCO 3
# down by 2-3%
# nan
# CSCO 4
# up by more than 5%
# nan
# CSCO 5
# down by 4-5%
# nan
# CSCO 6
# up by 1-2%
# nan
# CSCO 7
# down by 1-2%
# nan
# CSCO 8
# up by 3-4%
# nan
# CSCO 9
# up by 0-1%
# nan
# CSCO 10
# up by 3-4%
# nan
# CSCO 11
# down by 1-2%
# nan
# CSCO 12
# down by 1-2%
# nan
# CSCO 13
# down by more than 5%
# nan
# CSCO 14
# up by 0-1%
# nan
# CSCO 15
# down by 2-3%
# nan
# CSCO 16
# up by 0-1%
# nan
# CSCO 17
# up by more than 5%
# nan
# CSCO 18
# up by 1-2%
# nan
# CSCO 19
# up by 0-1%
# nan
# CVX 0
# up by 1-2%
# nan
# CVX 1
# down by 0-1%
# nan
# CVX 2
# down by more than 5%
# nan
# CVX 3
# up by 1-2%
# nan
# CVX 4
# down by 4-5%
# nan
# CVX 5
# down by 0-1%
# nan
# CVX 6
# up by 1-2%
# nan
# CVX 7
# down by 3-4%
# nan
# CVX 8
# down by 4-5%
# nan
# CVX 9
# up by 2-3%
# nan
# CVX 10
# up by 4-5%
# nan
# CVX 11
# up by 2-3%
# nan
# CVX 12
# up by 2-3%
# nan
# CVX 13
# down by 1-2%
# nan
# CVX 14
# down by 0-1%
# nan
# CVX 15
# down by 4-5%
# nan
# CVX 16
# down by 2-3%
# nan
# CVX 17
# up by 0-1%
# nan
# CVX 18
# down by 0-1%
# nan
# CVX 19
# down by 0-1%
# nan
# GS 0
# down by more than 5%
# nan
# GS 1
# up by 3-4%
# nan
# GS 2
# up by 4-5%
# nan
# GS 3
# up by 0-1%
# nan
# GS 4
# down by 0-1%
# nan
# GS 5
# down by 1-2%
# nan
# GS 6
# down by 1-2%
# nan
# GS 7
# down by more than 5%
# nan
# GS 8
# down by more than 5%
# nan
# GS 9
# up by 2-3%
# nan
# GS 10
# up by 4-5%
# nan
# GS 11
# down by 1-2%
# nan
# GS 12
# up by 4-5%
# nan
# GS 13
# up by 1-2%
# nan
# GS 14
# up by 0-1%
# nan
# GS 15
# down by 4-5%
# nan
# GS 16
# down by 2-3%
# nan
# GS 17
# up by 2-3%
# nan
# GS 18
# up by 1-2%
# nan
# GS 19
# down by 0-1%
# nan
# HD 0
# down by 4-5%
# nan
# HD 1
# up by 0-1%
# nan
# HD 2
# up by 4-5%
# nan
# HD 3
# down by 4-5%
# nan
# HD 4
# up by 0-1%
# nan
# HD 5
# down by more than 5%
# nan
# HD 6
# up by 0-1%
# nan
# HD 7
# down by 3-4%
# nan
# HD 8
# up by 0-1%
# nan
# HD 9
# down by 1-2%
# nan
# HD 10
# up by 4-5%
# nan
# HD 11
# down by 2-3%
# nan
# HD 12
# up by 1-2%
# nan
# HD 13
# up by 2-3%
# nan
# HD 14
# up by 0-1%
# nan
# HD 15
# down by 3-4%
# nan
# HD 16
# up by 0-1%
# nan
# HD 17
# up by 0-1%
# nan
# HD 18
# up by 0-1%
# nan
# HD 19
# down by 0-1%
# nan
# HON 0
# down by more than 5%
# nan
# HON 1
# up by 3-4%
# nan
# HON 2
# down by 2-3%
# nan
# HON 3
# down by 1-2%
# nan
# HON 4
# up by 0-1%
# nan
# HON 5
# down by 4-5%
# nan
# HON 6
# up by 2-3%
# nan
# HON 7
# down by 1-2%
# nan
# HON 8
# down by 4-5%
# nan
# HON 9
# up by 1-2%
# nan
# HON 10
# up by 1-2%
# nan
# HON 11
# down by 0-1%
# nan
# HON 12
# up by 3-4%
# nan
# HON 13
# down by 0-1%
# nan
# HON 14
# up by 1-2%
# nan
# HON 15
# down by 0-1%
# nan
# HON 16
# down by 1-2%
# nan
# HON 17
# up by 1-2%
# nan
# HON 18
# down by 1-2%
# nan
# HON 19
# up by 0-1%
# nan
# IBM 0
# down by 3-4%
# nan
# IBM 1
# down by 4-5%
# nan
# IBM 2
# up by 1-2%
# nan
# IBM 3
# up by 0-1%
# nan
# IBM 4
# down by 0-1%
# nan
# IBM 5
# down by 3-4%
# nan
# IBM 6
# down by 0-1%
# nan
# IBM 7
# down by 3-4%
# nan
# IBM 8
# down by 1-2%
# nan
# IBM 9
# up by 1-2%
# nan
# IBM 10
# up by 4-5%
# nan
# IBM 11
# down by 0-1%
# nan
# IBM 12
# down by 1-2%
# nan
# IBM 13
# down by 1-2%
# nan
# IBM 14
# up by 0-1%
# nan
# IBM 15
# down by 2-3%
# nan
# IBM 16
# up by 0-1%
# nan
# IBM 17
# up by 3-4%
# nan
# IBM 18
# up by 1-2%
# nan
# IBM 19
# up by 0-1%
# nan
# INTC 0
# down by 2-3%
# nan
# INTC 1
# down by 3-4%
# nan
# INTC 2
# up by more than 5%
# nan
# INTC 3
# down by more than 5%
# nan
# nan
# UNH 12
# down by 0-1%
# nan
# UNH 13
# down by more than 5%
# nan
# UNH 14
# up by 1-2%
# nan
# UNH 15
# up by 0-1%
# nan
# UNH 16
# down by 0-1%
# nan
# UNH 17
# down by 2-3%
# nan
# UNH 18
# up by 0-1%
# nan
# UNH 19
# down by 0-1%
# nan
# CRM 0
# up by 1-2%
# nan
# CRM 1
# up by more than 5%
# nan
# CRM 2
# up by 3-4%
# nan
# CRM 3
# down by 2-3%
# nan
# CRM 4
# down by 1-2%
# nan
# CRM 5
# down by 1-2%
# nan
# CRM 6
# up by more than 5%
# nan
# CRM 7
# down by more than 5%
# nan
# CRM 8
# up by more than 5%
# nan
# CRM 9
# up by 2-3%
# nan
# CRM 10
# up by more than 5%
# nan
# CRM 11
# down by 3-4%
# nan
# CRM 12
# up by 1-2%
# nan
# CRM 13
# up by 2-3%
# nan
# CRM 14
# down by 0-1%
# nan
# CRM 15
# down by 0-1%
# nan
# CRM 16
# up by 2-3%
# nan
# CRM 17
# up by 4-5%
# nan
# CRM 18
# up by 2-3%
# nan
# CRM 19
# up by 1-2%
# nan
# VZ 0
# down by 4-5%
# nan
# VZ 1
# up by 1-2%
# nan
# VZ 2
# up by 2-3%
# nan
# VZ 3
# down by 3-4%
# nan
# VZ 4
# up by 0-1%
# nan
# VZ 5
# down by 3-4%
# nan
# VZ 6
# down by 1-2%
# nan
# VZ 7
# down by 4-5%
# nan
# VZ 8
# up by 0-1%
# nan
# VZ 9
# up by 2-3%
# nan
# VZ 10
# up by 3-4%
# nan
# VZ 11
# up by 3-4%
# nan
# VZ 12
# down by 0-1%
# nan
# VZ 13
# down by 4-5%
# nan
# VZ 14
# up by 4-5%
# nan
# VZ 15
# down by 2-3%
# nan
# VZ 16
# down by 0-1%
# nan
# VZ 17
# down by 4-5%
# nan
# VZ 18
# down by 2-3%
# nan
# VZ 19
# down by 0-1%
# nan
# V 0
# up by 0-1%
# nan
# V 1
# up by 3-4%
# nan
# V 2
# down by 0-1%
# nan
# V 3
# down by 1-2%
# nan
# V 4
# down by 1-2%
# nan
# V 5
# down by 1-2%
# nan
# V 6
# up by 1-2%
# nan
# V 7
# down by 3-4%
# nan
# V 8
# up by 0-1%
# nan
# V 9
# up by 1-2%
# nan
# V 10
# up by 1-2%
# nan
# V 11
# up by 0-1%
# nan
# V 12
# up by 3-4%
# nan
# V 13
# up by 0-1%
# nan
# V 14
# down by 0-1%
# nan
# V 15
# down by 0-1%
# nan
# V 16
# up by 0-1%
# nan
# V 17
# up by 0-1%
# nan
# V 18
# down by 3-4%
# nan
# V 19
# down by 1-2%
# nan
# WBA 0
# down by 2-3%
# nan
# WBA 1
# up by 3-4%
# nan
# WBA 2
# down by 0-1%
# nan
# WBA 3
# down by 1-2%
# nan
# WBA 4
# up by 1-2%
# nan
# WBA 5
# down by 2-3%
# nan
# WBA 6
# up by 0-1%
# nan
# WBA 7
# down by more than 5%
# nan
# WBA 8
# down by 1-2%
# nan
# WBA 9
# down by 0-1%
# nan
# WBA 10
# up by more than 5%
# nan
# WBA 11
# up by 3-4%
# nan
# WBA 12
# down by 1-2%
# nan
# WBA 13
# down by 0-1%
# nan
# WBA 14
# down by 0-1%
# nan
# WBA 15
# down by more than 5%
# nan
# WBA 16
# down by 3-4%
# nan
# WBA 17
# up by 2-3%
# nan
# WBA 18
# down by 4-5%
# nan
# WBA 19
# down by 0-1%
# nan
# WMT 0
# down by 3-4%
# nan
# WMT 1
# up by 1-2%
# nan
# WMT 2
# down by 1-2%
# nan
# WMT 3
# up by 1-2%
# nan
# WMT 4
# up by 1-2%
# nan
# WMT 5
# down by 2-3%
# nan
# WMT 6
# down by 1-2%
# nan
# WMT 7
# down by 2-3%
# nan
# WMT 8
# up by 2-3%
# nan
# WMT 9
# up by 1-2%
# nan
# WMT 10
# up by 3-4%
# nan
# WMT 11
# up by 2-3%
# nan
# WMT 12
# down by 1-2%
# nan
# WMT 13
# up by 2-3%
# nan
# WMT 14
# down by 0-1%
# nan
# WMT 15
# up by 0-1%
# nan
# WMT 16
# up by 0-1%
# nan
# WMT 17
# down by 2-3%
# nan
# WMT 18
# down by 2-3%
# nan
# WMT 19
# down by 0-1%
# nan
# DIS 0
# up by 4-5%
# nan
# DIS 1
# up by more than 5%
# nan
# DIS 2
# up by 1-2%
# nan
# DIS 3
# down by 2-3%
# nan
# DIS 4
# down by 2-3%
# nan
# DIS 5
# down by 4-5%
# nan
# DIS 6
# up by 0-1%
# nan
# DIS 7
# down by more than 5%
# nan
# DIS 8
# down by 0-1%
# nan
# DIS 9
# up by 0-1%
# nan
# DIS 10
# up by more than 5%
# nan
# DIS 11
# down by 0-1%
# nan
# DIS 12
# down by 0-1%
# nan
# DIS 13
# down by 0-1%
# nan
# DIS 14
# up by 2-3%
# nan
# DIS 15
# down by 1-2%
# nan
# DIS 16
# down by more than 5%
# nan
# DIS 17
# down by 0-1%
# nan
# DIS 18
# down by 3-4%
# nan
# DIS 19
# down by 0-1%
# nan
# DOW 0
# down by 2-3%
# nan
# DOW 1
# up by 2-3%
# nan
# DOW 2
# up by 1-2%
# nan
# DOW 3
# down by 0-1%
# nan
# DOW 4
# down by 2-3%
# nan
# DOW 5
# down by 0-1%
# nan
# DOW 6
# up by 2-3%
# nan
# DOW 7
# down by more than 5%
# nan
# DOW 8
# down by more than 5%
# nan
# DOW 9
# up by 3-4%
# nan
# DOW 10
# up by more than 5%
# nan
# DOW 11
# down by 0-1%
# nan
# DOW 12
# up by 3-4%
# nan
# DOW 13
# down by 2-3%
# nan
# DOW 14
# down by 0-1%
# nan
# DOW 15
# up by 0-1%
# nan
# DOW 16
# down by 3-4%
# nan
# DOW 17
# down by 0-1%
# nan
# DOW 18
# down by 3-4%
# nan
# DOW 19
# down by 0-1%
# nan

# %%
# dow30_dataset.save_to_disk('fingpt-forecaster-dow30-20230601-20230930-llama')
# dow30_nobasics_dataset.save_to_disk('fingpt-forecaster-dow30nobasics-20230601-20230930-llama')
dow30_v3_dataset.save_to_disk('fingpt-forecaster-dow30v3-20221231-20230531-llama')
# Out:
# Saving the dataset (0/1 shards): 0 examples [00:00, ? examples/s]
# Saving the dataset (0/1 shards): 0 examples [00:00, ? examples/s]

# %%
dow30_v3_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['prompt', 'answer', 'period', 'label', 'symbol'],
#         num_rows: 0
#     })
#     test: Dataset({
#         features: ['prompt', 'answer', 'period', 'label', 'symbol'],
#         num_rows: 0
#     })
# })

# %%
import yfinance as yf
import pandas as pd
from datetime import date, datetime, timedelta


def get_curday():

    return date.today().strftime("%Y-%m-%d")


def n_weeks_before(date_string, n):

    date = datetime.strptime(date_string, "%Y-%m-%d") - timedelta(days=7*n)

    return date.strftime("%Y-%m-%d")


def get_stock_data(stock_symbol, steps):

    stock_data = yf.download(stock_symbol, steps[0], steps[-1])

#     print(stock_data)

    dates, prices = [], []
    available_dates = stock_data.index.format()

    for date in steps[:-1]:
        for i in range(len(stock_data)):
            if available_dates[i] >= date:
                prices.append(stock_data['Close'][i])
                dates.append(datetime.strptime(available_dates[i], "%Y-%m-%d"))
                break

    dates.append(datetime.strptime(available_dates[-1], "%Y-%m-%d"))
    prices.append(stock_data['Close'][-1])

    return pd.DataFrame({
        "Start Date": dates[:-1], "End Date": dates[1:],
        "Start Price": prices[:-1], "End Price": prices[1:]
    })


def get_current_basics(symbol, curday):

    basic_financials = finnhub_client.company_basic_financials(symbol, 'all')

    final_basics, basic_list, basic_dict = [], [], defaultdict(dict)

    for metric, value_list in basic_financials['series']['quarterly'].items():
        for value in value_list:
            basic_dict[value['period']].update({metric: value['v']})

    for k, v in basic_dict.items():
        v.update({'period': k})
        basic_list.append(v)

    basic_list.sort(key=lambda x: x['period'])

    for basic in basic_list[::-1]:
        if basic['period'] <= curday:
            break

    return basic


def get_all_prompts_online(symbol, data, curday, with_basics=True):

    company_prompt = get_company_prompt(symbol)

    prev_rows = []

    for row_idx, row in data.iterrows():
        head, news, _ = get_prompt_by_row(symbol, row)
        prev_rows.append((head, news, None))

    prompt = ""
    for i in range(-len(prev_rows), 0):
        prompt += "\n" + prev_rows[i][0]
        sampled_news = sample_news(
            prev_rows[i][1],
            min(5, len(prev_rows[i][1]))
        )
        if sampled_news:
            prompt += "\n".join(sampled_news)
        else:
            prompt += "No relative news reported."

    period = "{} to {}".format(curday, n_weeks_before(curday, -1))

    if with_basics:
        basics = get_current_basics(symbol, curday)
        basics = "Some recent basic financials of {}, reported at {}, are presented below:\n\n[Basic Financials]:\n\n".format(
            symbol, basics['period']) + "\n".join(f"{k}: {v}" for k, v in basics.items() if k != 'period')
    else:
        basics = "[Basic Financials]:\n\nNo basic financial reported."

    info = company_prompt + '\n' + prompt + '\n' + basics
    prompt = info + f"\n\nBased on all the information before {curday}, let's first analyze the positive developments and potential concerns for {symbol}. Come up with 2-4 most important factors respectively and keep them concise. Most factors should be inferred from company related news. " \
        f"Then make your prediction of the {symbol} stock price movement for next week ({period}). Provide a summary analysis to support your prediction."

    return info, prompt

# %%
from datetime import date

# %%
def get_curday():

    return date.today().strftime("%Y-%m-%d")


def n_weeks_before(date_string, n):

    date = datetime.strptime(date_string, "%Y-%m-%d") - timedelta(days=7*n)

    return date.strftime("%Y-%m-%d")

def get_stock_data(stock_symbol, steps):
  stock_data = yf.download(ticker, steps[0], steps[-1])

  #     print(stock_data)

  dates, prices = [], []
  available_dates = stock_data.index.format()

  for date in steps[:-1]:
      for i in range(len(stock_data)):
          if available_dates[i] >= date:
              prices.append(stock_data.iloc[i,0])
              dates.append(datetime.strptime(available_dates[i], "%Y-%m-%d"))
              break

  dates.append(datetime.strptime(available_dates[-1], "%Y-%m-%d"))
  prices.append(stock_data.iloc[-1,0])

  return pd.DataFrame({
        "Start Date": dates[:-1], "End Date": dates[1:],
        "Start Price": prices[:-1], "End Price": prices[1:]
    })

# %%
ticker = "AAPL"
n_weeks = 2
curday = get_curday()
steps = [n_weeks_before(curday, n) for n in range(n_weeks + 1)][::-1]

data = get_stock_data(ticker, steps)

data = get_news(ticker, data)

data['Basics'] = [json.dumps({})] * len(data)
# data = get_basics(ticker, data, always=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-131-4bb7378ef82c>:18: FutureWarning: DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   available_dates = stock_data.index.format()
# AAPL :  2025-01-29  -  2025-02-05
# AAPL :  2025-02-05  -  2025-02-11

# %%
info, prompt = get_all_prompts_online(ticker, data, curday, False)

print(prompt)
# Out:
# [Company Introduction]:
#
# Apple Inc is a leading entity in the Technology sector. Incorporated and publicly traded since 1980-12-12, the company has established its reputation as one of the key players in the market. As of today, Apple Inc has a market capitalization of 3494434.58 in USD, with 15115.82 shares outstanding.
#
# Apple Inc operates primarily in the US, trading under the ticker AAPL on the NASDAQ NMS - GLOBAL MARKET. As a dominant force in the Technology space, the company continues to innovate and drive progress within the industry.
#
# From 2025-01-29 to 2025-02-05, AAPL's stock price decreased from 239.10 to 232.21. Company news during this period are listed below:
#
# [Headline]: Apple Beats Earnings Target On Services Lift, But iPhone Sales Decline
# [Summary]: Apple Beats Earnings Target On Services Lift, But iPhone Sales Decline
#
# [Headline]: 'Magnificent Seven' stocks see big gains after Apple earnings
# [Summary]: 'Magnificent Seven' stocks see big gains after Apple earnings
#
# [Headline]: Apple escaped tariffs last time. This time, it may have to raise prices.
# [Summary]: Apple escaped tariffs last time. This time, it may have to raise prices.
#
# [Headline]: Baron Opportunity Fund Q4 2024 Shareholder Letter
# [Summary]: Baron Opportunity Fund increased in the fourth quarter of 2024, outperforming its benchmark, the Russell 3000 Growth Index.
#
# [Headline]: My Top 5 Dividend-Paying Buy-And-Hold Stocks For 2025
# [Summary]:
#
# From 2025-02-05 to 2025-02-11, AAPL's stock price increased from 232.21 to 232.62. Company news during this period are listed below:
#
# [Headline]: China Mulls Probe Into Apple's App Store, Bloomberg Reports, Citing Sources
# [Summary]: China's State Administration for Market Regulation is examining Apple's policies, which include taking a cut of as much as 30% on in-app spending and barring external payment services and stores,...
#
# [Headline]: Why Arm Holdings Stock Is Falling Despite Blockbuster Earnings Growth
# [Summary]: Arm Holdings plc excels in the semi industry with strategic partnerships and promising financials. Click here to find out why I rate ARM a Hold.
#
# [Headline]: Do you have too much of your money invested in the stock market?
# [Summary]: Do you have too much of your money invested in the stock market?
#
# [Headline]: Top 50 High-Quality Dividend Stocks For February 2025
# [Summary]: Discover 9 top dividend stocks with 10%+ 5-year return potential based on my valuations and in-depth analysis. Click here.
#
# [Headline]: Did Berkshire Sell More Apple or Bank of America Stock? We Should Know on Friday.
# [Summary]: Did Berkshire Sell More Apple or Bank of America Stock? We Should Know on Friday.
#
# [Basic Financials]:
#
# No basic financial reported.
#
# Based on all the information before 2025-02-12, let's first analyze the positive developments and potential concerns for AAPL. Come up with 2-4 most important factors respectively and keep them concise. Most factors should be inferred from company related news. Then make your prediction of the AAPL stock price movement for next week (2025-02-12 to 2025-02-19). Provide a summary analysis to support your prediction.

# %% [markdown]
# ## Run FinGPT Forecaster with Data

# %%
SYSTEM_PROMPT = "You are a seasoned stock market analyst. Your task is to list the positive developments and potential concerns for companies based on relevant news and basic financials from the past weeks, then provide an analysis and prediction for the companies' stock price movement for the upcoming week. Your answer format should be as follows:\n\n[Positive Developments]:\n1. ...\n\n[Potential Concerns]:\n1. ...\n\n[Prediction & Analysis]:\n...\n"

# %%
B_INST, E_INST = "[INST]", "[/INST]"
B_SYS, E_SYS = "<<SYS>>\n", "\n<</SYS>>\n\n"

prompt = B_INST + B_SYS + SYSTEM_PROMPT + E_SYS + prompt + E_INST
inputs = tokenizer(
    prompt, return_tensors='pt'
)
inputs = {key: value.to(model.device) for key, value in inputs.items()}

# %%
model = model.to(torch.float32)

# %%
res = model.generate(
    **inputs, max_length=4096, do_sample=True,
    eos_token_id=tokenizer.eos_token_id,
    use_cache=True
)
output = tokenizer.decode(res[0], skip_special_tokens=True)
answer = re.sub(r'.*\[/INST\]\s*', '', output, flags=re.DOTALL)

# %%
print(answer)
# Out:
# [Positive Developments]:
#
# 1. Apple beat its earnings target, indicating strong financial health and performance.
# 2. The company's services division is performing well, which could provide a stable source of income.
# 3. The company's stock price has shown a slight increase in the past week, indicating a potential recovery.
#
# [Potential Concerns]:
#
# 1. Apple's iPhone sales have been in decline, which could impact its revenue and profitability.
# 2. The company may face tariffs and potential price hikes, which could increase its costs and reduce its competitiveness.
# 3. The company's app store policies have been under scrutiny, which could lead to regulatory changes that may affect its profitability.
#
# [Prediction & Analysis]:
#
# Based on the above analysis, I predict that Apple's stock price will decrease by around 2-3% in the coming week (2025-02-12 to 2025-02-19). This prediction is based on the following factors:
#
# 1. The company's iPhone sales have been in decline, which could impact its revenue and profitability.
# 2. The company may face tariffs and potential price hikes, which could increase its costs and reduce its competitiveness.
# 3. The company's app store policies have been under scrutiny, which could lead to regulatory changes that may affect its profitability.
#
# However, it's worth noting that Apple has a strong brand and a loyal customer base, which could provide a buffer against some of these concerns. Additionally, the company's services division is performing well, which could provide a stable source of income.
#
# Overall, while there are some potential concerns, I believe that Apple's stock price will still experience some downward pressure in the coming week due to the decline in iPhone sales and the potential regulatory changes. However, the company's strong brand and loyal customer base could limit the extent of the decrease.
